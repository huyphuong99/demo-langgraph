# %%
from typing import Annotated

from typing_extensions import TypedDict

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages


class State(TypedDict):
    # Messages have the type "list". The `add_messages` function
    # in the annotation defines how this state key should be updated
    # (in this case, it appends messages to the list, rather than overwriting them)
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)

# %%
from langchain_anthropic import ChatAnthropic

llm = ChatAnthropic(model="claude-3-5-sonnet-20240620")


def chatbot(state: State):
    return {"messages": [llm.invoke(state["messages"])]}


# The first argument is the unique node name
# The second argument is the function or object that will be called whenever
# the node is used.
graph_builder.add_node("chatbot", chatbot)

# %%
graph_builder.add_edge(START, "chatbot")

# %%
graph_builder.add_edge("chatbot", END)

# %%
graph = graph_builder.compile()

# %%
from typing import Annotated

from typing_extensions import TypedDict

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages


class State(TypedDict):
    # Messages have the type "list". The `add_messages` function
    # in the annotation defines how this state key should be updated
    # (in this case, it appends messages to the list, rather than overwriting them)
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)

# %%
from langchain_anthropic import ChatAnthropic

llm = ChatAnthropic(model="claude-3-5-sonnet-20240620")

def chatbot(state: State):
    return {"messages": [llm.invoke(state["messages"])]}


# The first argument is the unique node name
# The second argument is the function or object that will be called whenever
# the node is used.
graph_builder.add_node("chatbot", chatbot)

# %%
graph_builder.add_edge(START, "chatbot")

# %%
graph_builder.add_edge("chatbot", END)

# %%
graph = graph_builder.compile()

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
def stream_graph_updates(user_input: str):
    for event in graph.stream({"messages": [{"role": "user", "content": user_input}]}):
        for value in event.values():
            print("Assistant:", value["messages"][-1].content)


while True:
    try:
        user_input = input("User: ")
        if user_input.lower() in ["quit", "exit", "q"]:
            print("Goodbye!")
            break
        stream_graph_updates(user_input)
    except:
        # fallback if input() is not available
        user_input = "What do you know about LangGraph?"
        print("User: " + user_input)
        stream_graph_updates(user_input)
        break
# Out:
# User: What do you know about LangGraph?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 13
#      12         break
# ---> 13     stream_graph_updates(user_input)
#      14 except:
#      15     # fallback if input() is not available
#
# Cell In[22], line 2, in stream_graph_updates(user_input)
#       1 def stream_graph_updates(user_input: str):
# ----> 2     for event in graph.stream({"messages": [{"role": "user", "content": user_input}]}):
#       3         for value in event.values():
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/__init__.py:2356, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2355 while loop.tick(input_keys=self.input_channels):
# -> 2356     for _ in runner.tick(
#    2357         loop.tasks.values(),
#    2358         timeout=self.step_timeout,
#    2359         retry_policy=self.retry_policy,
#    2360         get_waiter=get_waiter,
#    2361     ):
#    2362         # emit output
#    2363         yield from output()
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/runner.py:158, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     157 try:
# --> 158     run_with_retry(
#     159         t,
#     160         retry_policy,
#     161         configurable={
#     162             CONFIG_KEY_CALL: partial(
#     163                 _call,
#     164                 weakref.ref(t),
#     165                 retry=retry_policy,
#     166                 futures=weakref.ref(futures),
#     167                 schedule_task=self.schedule_task,
#     168                 submit=self.submit,
#     169                 reraise=reraise,
#     170             ),
#     171         },
#     172     )
#     173     self.commit(t, None)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/retry.py:39, in run_with_retry(task, retry_policy, configurable)
#      38     # run the task
# ---> 39     return task.proc.invoke(task.input, config)
#      40 except ParentCommand as exc:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:622, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     with set_config_context(config, run) as context:
# --> 622         input = context.run(step.invoke, input, config, **kwargs)
#     623 else:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:376, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375 else:
# --> 376     ret = self.func(*args, **kwargs)
#     377 if self.recurse and isinstance(ret, Runnable):
#
# Cell In[17], line 7, in chatbot(state)
#       6 def chatbot(state: State):
# ----> 7     return {"messages": [llm.invoke(state["messages"])]}
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:331, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     328 config = ensure_config(config)
#     329 return cast(
#     330     "ChatGeneration",
# --> 331     self.generate_prompt(
#     332         [self._convert_input(input)],
#     333         stop=stop,
#     334         callbacks=config.get("callbacks"),
#     335         tags=config.get("tags"),
#     336         metadata=config.get("metadata"),
#     337         run_name=config.get("run_name"),
#     338         run_id=config.pop("run_id", None),
#     339         **kwargs,
#     340     ).generations[0][0],
#     341 ).message
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:894, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     893 prompt_messages = [p.to_messages() for p in prompts]
# --> 894 return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:719, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     717 try:
#     718     results.append(
# --> 719         self._generate_with_cache(
#     720             m,
#     721             stop=stop,
#     722             run_manager=run_managers[i] if run_managers else None,
#     723             **kwargs,
#     724         )
#     725     )
#     726 except BaseException as e:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:960, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     959 if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 960     result = self._generate(
#     961         messages, stop=stop, run_manager=run_manager, **kwargs
#     962     )
#     963 else:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_anthropic/chat_models.py:1102, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1101 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# -> 1102 data = self._client.messages.create(**payload)
#    1103 return self._format_output(data, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/resources/messages/messages.py:953, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     947     warnings.warn(
#     948         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     949         DeprecationWarning,
#     950         stacklevel=3,
#     951     )
# --> 953 return self._post(
#     954     "/v1/messages",
#     955     body=maybe_transform(
#     956         {
#     957             "max_tokens": max_tokens,
#     958             "messages": messages,
#     959             "model": model,
#     960             "metadata": metadata,
#     961             "stop_sequences": stop_sequences,
#     962             "stream": stream,
#     963             "system": system,
#     964             "temperature": temperature,
#     965             "thinking": thinking,
#     966             "tool_choice": tool_choice,
#     967             "tools": tools,
#     968             "top_k": top_k,
#     969             "top_p": top_p,
#     970         },
#     971         message_create_params.MessageCreateParams,
#     972     ),
#     973     options=make_request_options(
#     974         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     975     ),
#     976     cast_to=Message,
#     977     stream=stream or False,
#     978     stream_cls=Stream[RawMessageStreamEvent],
#     979 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1336, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1333 opts = FinalRequestOptions.construct(
#    1334     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1335 )
# -> 1336 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1013, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1011     retries_taken = 0
# -> 1013 return self._request(
#    1014     cast_to=cast_to,
#    1015     options=options,
#    1016     stream=stream,
#    1017     stream_cls=stream_cls,
#    1018     retries_taken=retries_taken,
#    1019 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1038 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
# -> 1039 request = self._build_request(options, retries_taken=retries_taken)
#    1040 self._prepare_request(request)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:487, in BaseClient._build_request(self, options, retries_taken)
#     485         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 487 headers = self._build_headers(options, retries_taken=retries_taken)
#     488 params = _merge_mappings(self.default_query, options.params)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:428, in BaseClient._build_headers(self, options, retries_taken)
#     419 headers_dict = _merge_mappings(
#     420     {
#     421         "x-stainless-timeout": str(options.timeout.read)
#    (...)
#     426     custom_headers,
#     427 )
# --> 428 self._validate_headers(headers_dict, custom_headers)
#     430 # headers are case-insensitive while dictionaries are not.
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_client.py:180, in Anthropic._validate_headers(self, headers, custom_headers)
#     178     return
# --> 180 raise TypeError(
#     181     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     182 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 18
#      16 user_input = "What do you know about LangGraph?"
#      17 print("User: " + user_input)
# ---> 18 stream_graph_updates(user_input)
#      19 break
#
# Cell In[22], line 2, in stream_graph_updates(user_input)
#       1 def stream_graph_updates(user_input: str):
# ----> 2     for event in graph.stream({"messages": [{"role": "user", "content": user_input}]}):
#       3         for value in event.values():
#       4             print("Assistant:", value["messages"][-1].content)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/__init__.py:2356, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2350     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2351     # computation proceeds in steps, while there are channel updates.
#    2352     # Channel updates from step N are only visible in step N+1
#    2353     # channels are guaranteed to be immutable for the duration of the step,
#    2354     # with channel updates applied only at the transition between steps.
#    2355     while loop.tick(input_keys=self.input_channels):
# -> 2356         for _ in runner.tick(
#    2357             loop.tasks.values(),
#    2358             timeout=self.step_timeout,
#    2359             retry_policy=self.retry_policy,
#    2360             get_waiter=get_waiter,
#    2361         ):
#    2362             # emit output
#    2363             yield from output()
#    2364 # emit output
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/runner.py:158, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     156 t = tasks[0]
#     157 try:
# --> 158     run_with_retry(
#     159         t,
#     160         retry_policy,
#     161         configurable={
#     162             CONFIG_KEY_CALL: partial(
#     163                 _call,
#     164                 weakref.ref(t),
#     165                 retry=retry_policy,
#     166                 futures=weakref.ref(futures),
#     167                 schedule_task=self.schedule_task,
#     168                 submit=self.submit,
#     169                 reraise=reraise,
#     170             ),
#     171         },
#     172     )
#     173     self.commit(t, None)
#     174 except Exception as exc:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/retry.py:39, in run_with_retry(task, retry_policy, configurable)
#      37     task.writes.clear()
#      38     # run the task
# ---> 39     return task.proc.invoke(task.input, config)
#      40 except ParentCommand as exc:
#      41     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:622, in RunnableSeq.invoke(self, input, config, **kwargs)
#     620     # run in context
#     621     with set_config_context(config, run) as context:
# --> 622         input = context.run(step.invoke, input, config, **kwargs)
#     623 else:
#     624     input = step.invoke(input, config)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:376, in RunnableCallable.invoke(self, input, config, **kwargs)
#     374         run_manager.on_chain_end(ret)
#     375 else:
# --> 376     ret = self.func(*args, **kwargs)
#     377 if self.recurse and isinstance(ret, Runnable):
#     378     return ret.invoke(input, config)
#
# Cell In[17], line 7, in chatbot(state)
#       6 def chatbot(state: State):
# ----> 7     return {"messages": [llm.invoke(state["messages"])]}
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:331, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     319 @override
#     320 def invoke(
#     321     self,
#    (...)
#     326     **kwargs: Any,
#     327 ) -> BaseMessage:
#     328     config = ensure_config(config)
#     329     return cast(
#     330         "ChatGeneration",
# --> 331         self.generate_prompt(
#     332             [self._convert_input(input)],
#     333             stop=stop,
#     334             callbacks=config.get("callbacks"),
#     335             tags=config.get("tags"),
#     336             metadata=config.get("metadata"),
#     337             run_name=config.get("run_name"),
#     338             run_id=config.pop("run_id", None),
#     339             **kwargs,
#     340         ).generations[0][0],
#     341     ).message
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:894, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     885 @override
#     886 def generate_prompt(
#     887     self,
#    (...)
#     891     **kwargs: Any,
#     892 ) -> LLMResult:
#     893     prompt_messages = [p.to_messages() for p in prompts]
# --> 894     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:719, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     716 for i, m in enumerate(messages):
#     717     try:
#     718         results.append(
# --> 719             self._generate_with_cache(
#     720                 m,
#     721                 stop=stop,
#     722                 run_manager=run_managers[i] if run_managers else None,
#     723                 **kwargs,
#     724             )
#     725         )
#     726     except BaseException as e:
#     727         if run_managers:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:960, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     958 else:
#     959     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 960         result = self._generate(
#     961             messages, stop=stop, run_manager=run_manager, **kwargs
#     962         )
#     963     else:
#     964         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_anthropic/chat_models.py:1102, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1100     return generate_from_stream(stream_iter)
#    1101 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# -> 1102 data = self._client.messages.create(**payload)
#    1103 return self._format_output(data, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/resources/messages/messages.py:953, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     946 if model in DEPRECATED_MODELS:
#     947     warnings.warn(
#     948         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     949         DeprecationWarning,
#     950         stacklevel=3,
#     951     )
# --> 953 return self._post(
#     954     "/v1/messages",
#     955     body=maybe_transform(
#     956         {
#     957             "max_tokens": max_tokens,
#     958             "messages": messages,
#     959             "model": model,
#     960             "metadata": metadata,
#     961             "stop_sequences": stop_sequences,
#     962             "stream": stream,
#     963             "system": system,
#     964             "temperature": temperature,
#     965             "thinking": thinking,
#     966             "tool_choice": tool_choice,
#     967             "tools": tools,
#     968             "top_k": top_k,
#     969             "top_p": top_p,
#     970         },
#     971         message_create_params.MessageCreateParams,
#     972     ),
#     973     options=make_request_options(
#     974         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     975     ),
#     976     cast_to=Message,
#     977     stream=stream or False,
#     978     stream_cls=Stream[RawMessageStreamEvent],
#     979 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1336, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1322 def post(
#    1323     self,
#    1324     path: str,
#    (...)
#    1331     stream_cls: type[_StreamT] | None = None,
#    1332 ) -> ResponseT | _StreamT:
#    1333     opts = FinalRequestOptions.construct(
#    1334         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1335     )
# -> 1336     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1013, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1010 else:
#    1011     retries_taken = 0
# -> 1013 return self._request(
#    1014     cast_to=cast_to,
#    1015     options=options,
#    1016     stream=stream,
#    1017     stream_cls=stream_cls,
#    1018     retries_taken=retries_taken,
#    1019 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1036 options = self._prepare_options(options)
#    1038 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
# -> 1039 request = self._build_request(options, retries_taken=retries_taken)
#    1040 self._prepare_request(request)
#    1042 kwargs: HttpxSendArgs = {}
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:487, in BaseClient._build_request(self, options, retries_taken)
#     484     else:
#     485         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 487 headers = self._build_headers(options, retries_taken=retries_taken)
#     488 params = _merge_mappings(self.default_query, options.params)
#     489 content_type = headers.get("Content-Type")
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:428, in BaseClient._build_headers(self, options, retries_taken)
#     418 custom_headers = options.headers or {}
#     419 headers_dict = _merge_mappings(
#     420     {
#     421         "x-stainless-timeout": str(options.timeout.read)
#    (...)
#     426     custom_headers,
#     427 )
# --> 428 self._validate_headers(headers_dict, custom_headers)
#     430 # headers are case-insensitive while dictionaries are not.
#     431 headers = httpx.Headers(headers_dict)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_client.py:180, in Anthropic._validate_headers(self, headers, custom_headers)
#     177 if isinstance(custom_headers.get("Authorization"), Omit):
#     178     return
# --> 180 raise TypeError(
#     181     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     182 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"

# %%
from typing import Annotated

from langchain_anthropic import ChatAnthropic
from typing_extensions import TypedDict

from langgraph.graph import StateGraph
from langgraph.graph.message import add_messages


class State(TypedDict):
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)


llm = ChatAnthropic(model="claude-3-5-sonnet-20240620")


def chatbot(state: State):
    return {"messages": [llm.invoke(state["messages"])]}


# The first argument is the unique node name
# The second argument is the function or object that will be called whenever
# the node is used.
graph_builder.add_node("chatbot", chatbot)
graph_builder.set_entry_point("chatbot")
graph_builder.set_finish_point("chatbot")
graph = graph_builder.compile()

# %%
from typing import Annotated

from langchain_anthropic import ChatAnthropic
from typing_extensions import TypedDict

from langgraph.graph import StateGraph
from langgraph.graph.message import add_messages


class State(TypedDict):
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)


llm = ChatAnthropic(model="claude-3-5-sonnet-20240620")


def chatbot(state: State):
    return {"messages": [llm.invoke(state["messages"])]}


# The first argument is the unique node name
# The second argument is the function or object that will be called whenever
# the node is used.
graph_builder.add_node("chatbot", chatbot)
graph_builder.set_entry_point("chatbot")
graph_builder.set_finish_point("chatbot")
graph = graph_builder.compile()

# %%
# %%capture --no-stderr
# %pip install -U tavily-python langchain_community

# %%
import getpass
import os
def _set_env(var: str):
    # if not os.environ.get(var):
    os.environ[var] = getpass.getpass(f"{var}: ")

# %%
_set_env("TAVILY_API_KEY")

# %%
from langchain_community.tools.tavily_search import TavilySearchResults

tool = TavilySearchResults(max_results=2)
tools = [tool]
tool.invoke("What's a 'node' in LangGraph?")
# Out:
# [{'title': 'A Comprehensive Guide About Langgraph: Code Included - Ionio',
#   'url': 'https://www.ionio.ai/blog/a-comprehensive-guide-about-langgraph-code-included',
#   'content': 'A node can be any function or tool your agent uses in langgraph and these nodes are connected with other nodes using edges. Every workflow ends with a “END”',
#   'score': 0.8872928},
#  {'title': 'What Is LangGraph and How to Use It? - DataCamp',
#   'url': 'https://www.datacamp.com/tutorial/langgraph-tutorial',
#   'content': 'To install LangGraph, you can use pip:\npip install -U langgraph\nPowered By \nWas this helpful? Yes No\nBasic Concepts\nNodes: Nodes represent units of work within your LangGraph. They are typically Python functions that perform a specific task, such as: [...] Imagine your application as a directed graph. In LangGraph, each node represents an LLM agent, and the edges are the communication channels between these agents. This structure allows for clear and manageable workflows, where each agent performs specific tasks and passes information to other agents as needed.\nState management [...] In LangGraph, you can add nodes using the graph.add_node(name, value) syntax.\nEdges: Edges are communication channels between nodes. They define the flow of information and the order of execution. You can add edges using the graph.add_edge(node1, node2) syntax.',
#   'score': 0.8820324}]

# %%
from typing import Annotated

from langchain_anthropic import ChatAnthropic
from typing_extensions import TypedDict

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages


class State(TypedDict):
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)


llm = ChatAnthropic(model="claude-3-5-sonnet-20240620")
# Modification: tell the LLM which tools it can call
llm_with_tools = llm.bind_tools(tools)


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}


graph_builder.add_node("chatbot", chatbot)

# %%
import json

from langchain_core.messages import ToolMessage


class BasicToolNode:
    """A node that runs the tools requested in the last AIMessage."""

    def __init__(self, tools: list) -> None:
        self.tools_by_name = {tool.name: tool for tool in tools}

    def __call__(self, inputs: dict):
        if messages := inputs.get("messages", []):
            message = messages[-1]
        else:
            raise ValueError("No message found in input")
        outputs = []
        for tool_call in message.tool_calls:
            tool_result = self.tools_by_name[tool_call["name"]].invoke(
                tool_call["args"]
            )
            outputs.append(
                ToolMessage(
                    content=json.dumps(tool_result),
                    name=tool_call["name"],
                    tool_call_id=tool_call["id"],
                )
            )
        return {"messages": outputs}


tool_node = BasicToolNode(tools=[tool])
graph_builder.add_node("tools", tool_node)

# %%
def route_tools(
    state: State,
):
    """
    Use in the conditional_edge to route to the ToolNode if the last message
    has tool calls. Otherwise, route to the end.
    """
    if isinstance(state, list):
        ai_message = state[-1]
    elif messages := state.get("messages", []):
        ai_message = messages[-1]
    else:
        raise ValueError(f"No messages found in input state to tool_edge: {state}")
    if hasattr(ai_message, "tool_calls") and len(ai_message.tool_calls) > 0:
        return "tools"
    return END


# The `tools_condition` function returns "tools" if the chatbot asks to use a tool, and "END" if
# it is fine directly responding. This conditional routing defines the main agent loop.
graph_builder.add_conditional_edges(
    "chatbot",
    route_tools,
    # The following dictionary lets you tell the graph to interpret the condition's outputs as a specific node
    # It defaults to the identity function, but if you
    # want to use a node named something else apart from "tools",
    # You can update the value of the dictionary to something else
    # e.g., "tools": "my_tools"
    {"tools": "tools", END: END},
)
# Any time a tool is called, we return to the chatbot to decide the next step
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")
graph = graph_builder.compile()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 34
#      21 graph_builder.add_conditional_edges(
#      22     "chatbot",
#      23     route_tools,
#    (...)
#      29     {"tools": "tools", END: END},
#      30 )
#      31 # Any time a tool is called, we return to the chatbot to decide the next step
#      32 # graph_builder.add_edge("tools", "chatbot")
#      33 # graph_builder.add_edge(START, "chatbot")
# ---> 34 graph = graph_builder.compile()
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/graph/state.py:613, in StateGraph.compile(self, checkpointer, store, interrupt_before, interrupt_after, debug, name)
#     610 interrupt_after = interrupt_after or []
#     612 # validate the graph
# --> 613 self.validate(
#     614     interrupt=(
#     615         (interrupt_before if interrupt_before != "*" else []) + interrupt_after
#     616         if interrupt_after != "*"
#     617         else []
#     618     )
#     619 )
#     621 # prepare output channels
#     622 output_channels = (
#     623     "__root__"
#     624     if len(self.schemas[self.output]) == 1
#    (...)
#     630     ]
#     631 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/graph/graph.py:264, in Graph.validate(self, interrupt)
#     262 for source in all_sources:
#     263     if source not in self.nodes and source != START:
# --> 264         raise ValueError(f"Found edge starting at unknown node '{source}'")
#     266 if START not in all_sources:
#     267     raise ValueError(
#     268         "Graph must have an entrypoint: add at least one edge from START to another node"
#     269     )
#
# ValueError: Found edge starting at unknown node 'tools'

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
while True:
    try:
        user_input = input("User: ")
        if user_input.lower() in ["quit", "exit", "q"]:
            print("Goodbye!")
            break

        stream_graph_updates(user_input)
    except:
        # fallback if input() is not available
        user_input = "What do you know about LangGraph?"
        print("User: " + user_input)
        stream_graph_updates(user_input)
        break
# Out:
# User: What do you know about LangGraph?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 8
#       6         break
# ----> 8     stream_graph_updates(user_input)
#       9 except:
#      10     # fallback if input() is not available
#
# Cell In[22], line 2, in stream_graph_updates(user_input)
#       1 def stream_graph_updates(user_input: str):
# ----> 2     for event in graph.stream({"messages": [{"role": "user", "content": user_input}]}):
#       3         for value in event.values():
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/__init__.py:2356, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2355 while loop.tick(input_keys=self.input_channels):
# -> 2356     for _ in runner.tick(
#    2357         loop.tasks.values(),
#    2358         timeout=self.step_timeout,
#    2359         retry_policy=self.retry_policy,
#    2360         get_waiter=get_waiter,
#    2361     ):
#    2362         # emit output
#    2363         yield from output()
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/runner.py:158, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     157 try:
# --> 158     run_with_retry(
#     159         t,
#     160         retry_policy,
#     161         configurable={
#     162             CONFIG_KEY_CALL: partial(
#     163                 _call,
#     164                 weakref.ref(t),
#     165                 retry=retry_policy,
#     166                 futures=weakref.ref(futures),
#     167                 schedule_task=self.schedule_task,
#     168                 submit=self.submit,
#     169                 reraise=reraise,
#     170             ),
#     171         },
#     172     )
#     173     self.commit(t, None)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/retry.py:39, in run_with_retry(task, retry_policy, configurable)
#      38     # run the task
# ---> 39     return task.proc.invoke(task.input, config)
#      40 except ParentCommand as exc:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:622, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     with set_config_context(config, run) as context:
# --> 622         input = context.run(step.invoke, input, config, **kwargs)
#     623 else:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:376, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375 else:
# --> 376     ret = self.func(*args, **kwargs)
#     377 if self.recurse and isinstance(ret, Runnable):
#
# Cell In[36], line 23, in chatbot(state)
#      22 def chatbot(state: State):
# ---> 23     return {"messages": [llm_with_tools.invoke(state["messages"])]}
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/runnables/base.py:5440, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5433 @override
#    5434 def invoke(
#    5435     self,
#    (...)
#    5438     **kwargs: Optional[Any],
#    5439 ) -> Output:
# -> 5440     return self.bound.invoke(
#    5441         input,
#    5442         self._merge_configs(config),
#    5443         **{**self.kwargs, **kwargs},
#    5444     )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:331, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     328 config = ensure_config(config)
#     329 return cast(
#     330     "ChatGeneration",
# --> 331     self.generate_prompt(
#     332         [self._convert_input(input)],
#     333         stop=stop,
#     334         callbacks=config.get("callbacks"),
#     335         tags=config.get("tags"),
#     336         metadata=config.get("metadata"),
#     337         run_name=config.get("run_name"),
#     338         run_id=config.pop("run_id", None),
#     339         **kwargs,
#     340     ).generations[0][0],
#     341 ).message
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:894, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     893 prompt_messages = [p.to_messages() for p in prompts]
# --> 894 return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:719, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     717 try:
#     718     results.append(
# --> 719         self._generate_with_cache(
#     720             m,
#     721             stop=stop,
#     722             run_manager=run_managers[i] if run_managers else None,
#     723             **kwargs,
#     724         )
#     725     )
#     726 except BaseException as e:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:960, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     959 if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 960     result = self._generate(
#     961         messages, stop=stop, run_manager=run_manager, **kwargs
#     962     )
#     963 else:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_anthropic/chat_models.py:1102, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1101 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# -> 1102 data = self._client.messages.create(**payload)
#    1103 return self._format_output(data, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/resources/messages/messages.py:953, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     947     warnings.warn(
#     948         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     949         DeprecationWarning,
#     950         stacklevel=3,
#     951     )
# --> 953 return self._post(
#     954     "/v1/messages",
#     955     body=maybe_transform(
#     956         {
#     957             "max_tokens": max_tokens,
#     958             "messages": messages,
#     959             "model": model,
#     960             "metadata": metadata,
#     961             "stop_sequences": stop_sequences,
#     962             "stream": stream,
#     963             "system": system,
#     964             "temperature": temperature,
#     965             "thinking": thinking,
#     966             "tool_choice": tool_choice,
#     967             "tools": tools,
#     968             "top_k": top_k,
#     969             "top_p": top_p,
#     970         },
#     971         message_create_params.MessageCreateParams,
#     972     ),
#     973     options=make_request_options(
#     974         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     975     ),
#     976     cast_to=Message,
#     977     stream=stream or False,
#     978     stream_cls=Stream[RawMessageStreamEvent],
#     979 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1336, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1333 opts = FinalRequestOptions.construct(
#    1334     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1335 )
# -> 1336 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1013, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1011     retries_taken = 0
# -> 1013 return self._request(
#    1014     cast_to=cast_to,
#    1015     options=options,
#    1016     stream=stream,
#    1017     stream_cls=stream_cls,
#    1018     retries_taken=retries_taken,
#    1019 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1038 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
# -> 1039 request = self._build_request(options, retries_taken=retries_taken)
#    1040 self._prepare_request(request)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:487, in BaseClient._build_request(self, options, retries_taken)
#     485         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 487 headers = self._build_headers(options, retries_taken=retries_taken)
#     488 params = _merge_mappings(self.default_query, options.params)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:428, in BaseClient._build_headers(self, options, retries_taken)
#     419 headers_dict = _merge_mappings(
#     420     {
#     421         "x-stainless-timeout": str(options.timeout.read)
#    (...)
#     426     custom_headers,
#     427 )
# --> 428 self._validate_headers(headers_dict, custom_headers)
#     430 # headers are case-insensitive while dictionaries are not.
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_client.py:180, in Anthropic._validate_headers(self, headers, custom_headers)
#     178     return
# --> 180 raise TypeError(
#     181     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     182 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 13
#      11 user_input = "What do you know about LangGraph?"
#      12 print("User: " + user_input)
# ---> 13 stream_graph_updates(user_input)
#      14 break
#
# Cell In[22], line 2, in stream_graph_updates(user_input)
#       1 def stream_graph_updates(user_input: str):
# ----> 2     for event in graph.stream({"messages": [{"role": "user", "content": user_input}]}):
#       3         for value in event.values():
#       4             print("Assistant:", value["messages"][-1].content)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/__init__.py:2356, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2350     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2351     # computation proceeds in steps, while there are channel updates.
#    2352     # Channel updates from step N are only visible in step N+1
#    2353     # channels are guaranteed to be immutable for the duration of the step,
#    2354     # with channel updates applied only at the transition between steps.
#    2355     while loop.tick(input_keys=self.input_channels):
# -> 2356         for _ in runner.tick(
#    2357             loop.tasks.values(),
#    2358             timeout=self.step_timeout,
#    2359             retry_policy=self.retry_policy,
#    2360             get_waiter=get_waiter,
#    2361         ):
#    2362             # emit output
#    2363             yield from output()
#    2364 # emit output
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/runner.py:158, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     156 t = tasks[0]
#     157 try:
# --> 158     run_with_retry(
#     159         t,
#     160         retry_policy,
#     161         configurable={
#     162             CONFIG_KEY_CALL: partial(
#     163                 _call,
#     164                 weakref.ref(t),
#     165                 retry=retry_policy,
#     166                 futures=weakref.ref(futures),
#     167                 schedule_task=self.schedule_task,
#     168                 submit=self.submit,
#     169                 reraise=reraise,
#     170             ),
#     171         },
#     172     )
#     173     self.commit(t, None)
#     174 except Exception as exc:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/retry.py:39, in run_with_retry(task, retry_policy, configurable)
#      37     task.writes.clear()
#      38     # run the task
# ---> 39     return task.proc.invoke(task.input, config)
#      40 except ParentCommand as exc:
#      41     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:622, in RunnableSeq.invoke(self, input, config, **kwargs)
#     620     # run in context
#     621     with set_config_context(config, run) as context:
# --> 622         input = context.run(step.invoke, input, config, **kwargs)
#     623 else:
#     624     input = step.invoke(input, config)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:376, in RunnableCallable.invoke(self, input, config, **kwargs)
#     374         run_manager.on_chain_end(ret)
#     375 else:
# --> 376     ret = self.func(*args, **kwargs)
#     377 if self.recurse and isinstance(ret, Runnable):
#     378     return ret.invoke(input, config)
#
# Cell In[36], line 23, in chatbot(state)
#      22 def chatbot(state: State):
# ---> 23     return {"messages": [llm_with_tools.invoke(state["messages"])]}
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/runnables/base.py:5440, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5433 @override
#    5434 def invoke(
#    5435     self,
#    (...)
#    5438     **kwargs: Optional[Any],
#    5439 ) -> Output:
# -> 5440     return self.bound.invoke(
#    5441         input,
#    5442         self._merge_configs(config),
#    5443         **{**self.kwargs, **kwargs},
#    5444     )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:331, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     319 @override
#     320 def invoke(
#     321     self,
#    (...)
#     326     **kwargs: Any,
#     327 ) -> BaseMessage:
#     328     config = ensure_config(config)
#     329     return cast(
#     330         "ChatGeneration",
# --> 331         self.generate_prompt(
#     332             [self._convert_input(input)],
#     333             stop=stop,
#     334             callbacks=config.get("callbacks"),
#     335             tags=config.get("tags"),
#     336             metadata=config.get("metadata"),
#     337             run_name=config.get("run_name"),
#     338             run_id=config.pop("run_id", None),
#     339             **kwargs,
#     340         ).generations[0][0],
#     341     ).message
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:894, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     885 @override
#     886 def generate_prompt(
#     887     self,
#    (...)
#     891     **kwargs: Any,
#     892 ) -> LLMResult:
#     893     prompt_messages = [p.to_messages() for p in prompts]
# --> 894     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:719, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     716 for i, m in enumerate(messages):
#     717     try:
#     718         results.append(
# --> 719             self._generate_with_cache(
#     720                 m,
#     721                 stop=stop,
#     722                 run_manager=run_managers[i] if run_managers else None,
#     723                 **kwargs,
#     724             )
#     725         )
#     726     except BaseException as e:
#     727         if run_managers:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:960, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     958 else:
#     959     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 960         result = self._generate(
#     961             messages, stop=stop, run_manager=run_manager, **kwargs
#     962         )
#     963     else:
#     964         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_anthropic/chat_models.py:1102, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1100     return generate_from_stream(stream_iter)
#    1101 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# -> 1102 data = self._client.messages.create(**payload)
#    1103 return self._format_output(data, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/resources/messages/messages.py:953, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     946 if model in DEPRECATED_MODELS:
#     947     warnings.warn(
#     948         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     949         DeprecationWarning,
#     950         stacklevel=3,
#     951     )
# --> 953 return self._post(
#     954     "/v1/messages",
#     955     body=maybe_transform(
#     956         {
#     957             "max_tokens": max_tokens,
#     958             "messages": messages,
#     959             "model": model,
#     960             "metadata": metadata,
#     961             "stop_sequences": stop_sequences,
#     962             "stream": stream,
#     963             "system": system,
#     964             "temperature": temperature,
#     965             "thinking": thinking,
#     966             "tool_choice": tool_choice,
#     967             "tools": tools,
#     968             "top_k": top_k,
#     969             "top_p": top_p,
#     970         },
#     971         message_create_params.MessageCreateParams,
#     972     ),
#     973     options=make_request_options(
#     974         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     975     ),
#     976     cast_to=Message,
#     977     stream=stream or False,
#     978     stream_cls=Stream[RawMessageStreamEvent],
#     979 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1336, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1322 def post(
#    1323     self,
#    1324     path: str,
#    (...)
#    1331     stream_cls: type[_StreamT] | None = None,
#    1332 ) -> ResponseT | _StreamT:
#    1333     opts = FinalRequestOptions.construct(
#    1334         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1335     )
# -> 1336     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1013, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1010 else:
#    1011     retries_taken = 0
# -> 1013 return self._request(
#    1014     cast_to=cast_to,
#    1015     options=options,
#    1016     stream=stream,
#    1017     stream_cls=stream_cls,
#    1018     retries_taken=retries_taken,
#    1019 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1036 options = self._prepare_options(options)
#    1038 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
# -> 1039 request = self._build_request(options, retries_taken=retries_taken)
#    1040 self._prepare_request(request)
#    1042 kwargs: HttpxSendArgs = {}
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:487, in BaseClient._build_request(self, options, retries_taken)
#     484     else:
#     485         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 487 headers = self._build_headers(options, retries_taken=retries_taken)
#     488 params = _merge_mappings(self.default_query, options.params)
#     489 content_type = headers.get("Content-Type")
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:428, in BaseClient._build_headers(self, options, retries_taken)
#     418 custom_headers = options.headers or {}
#     419 headers_dict = _merge_mappings(
#     420     {
#     421         "x-stainless-timeout": str(options.timeout.read)
#    (...)
#     426     custom_headers,
#     427 )
# --> 428 self._validate_headers(headers_dict, custom_headers)
#     430 # headers are case-insensitive while dictionaries are not.
#     431 headers = httpx.Headers(headers_dict)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_client.py:180, in Anthropic._validate_headers(self, headers, custom_headers)
#     177 if isinstance(custom_headers.get("Authorization"), Omit):
#     178     return
# --> 180 raise TypeError(
#     181     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     182 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"

# %%
# !pip show langgraph
# Out:
# Name: langgraph
# Version: 0.3.30
# Summary: Building stateful, multi-actor applications with LLMs
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: /Users/nguyenhuyphuong/miniforge3/envs/genai/lib/python3.10/site-packages
# Requires: langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph-sdk, xxhash
# Required-by:

# %%
from typing import Annotated

from langchain_anthropic import ChatAnthropic
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.messages import BaseMessage
from typing_extensions import TypedDict

from langgraph.graph import StateGraph
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode, tools_condition


class State(TypedDict):
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)


tool = TavilySearchResults(max_results=2)
tools = [tool]
llm = ChatAnthropic(model="claude-3-5-sonnet-20240620")
llm_with_tools = llm.bind_tools(tools)


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}


graph_builder.add_node("chatbot", chatbot)

tool_node = ToolNode(tools=[tool])
graph_builder.add_node("tools", tool_node)

graph_builder.add_conditional_edges(
    "chatbot",
    tools_condition,
)
# Any time a tool is called, we return to the chatbot to decide the next step
graph_builder.add_edge("tools", "chatbot")
graph_builder.set_entry_point("chatbot")
graph = graph_builder.compile()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[59], line 10
#       8 from langgraph.graph import StateGraph
#       9 from langgraph.graph.message import add_messages
# ---> 10 from langgraph.prebuilt import ToolNode, tools_condition
#      13 class State(TypedDict):
#      14     messages: Annotated[list, add_messages]
#
# ImportError: cannot import name 'ToolNode' from 'langgraph.prebuilt' (unknown location)

# %%
config = {"configurable": {"thread_id": "1"}}
events = graph.stream(
    {
        "messages": [
            {
                "role": "user",
                "content": (
                    "I'm learning LangGraph. "
                    "Could you do some research on it for me?"
                ),
            },
        ],
    },
    config,
    stream_mode="values",
)
for event in events:
    if "messages" in event:
        event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# I'm learning LangGraph. Could you do some research on it for me?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 17
#       1 config = {"configurable": {"thread_id": "1"}}
#       2 events = graph.stream(
#       3     {
#       4         "messages": [
#    (...)
#      15     stream_mode="values",
#      16 )
# ---> 17 for event in events:
#      18     if "messages" in event:
#      19         event["messages"][-1].pretty_print()
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/__init__.py:2356, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2350     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2351     # computation proceeds in steps, while there are channel updates.
#    2352     # Channel updates from step N are only visible in step N+1
#    2353     # channels are guaranteed to be immutable for the duration of the step,
#    2354     # with channel updates applied only at the transition between steps.
#    2355     while loop.tick(input_keys=self.input_channels):
# -> 2356         for _ in runner.tick(
#    2357             loop.tasks.values(),
#    2358             timeout=self.step_timeout,
#    2359             retry_policy=self.retry_policy,
#    2360             get_waiter=get_waiter,
#    2361         ):
#    2362             # emit output
#    2363             yield from output()
#    2364 # emit output
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/runner.py:158, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     156 t = tasks[0]
#     157 try:
# --> 158     run_with_retry(
#     159         t,
#     160         retry_policy,
#     161         configurable={
#     162             CONFIG_KEY_CALL: partial(
#     163                 _call,
#     164                 weakref.ref(t),
#     165                 retry=retry_policy,
#     166                 futures=weakref.ref(futures),
#     167                 schedule_task=self.schedule_task,
#     168                 submit=self.submit,
#     169                 reraise=reraise,
#     170             ),
#     171         },
#     172     )
#     173     self.commit(t, None)
#     174 except Exception as exc:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/retry.py:39, in run_with_retry(task, retry_policy, configurable)
#      37     task.writes.clear()
#      38     # run the task
# ---> 39     return task.proc.invoke(task.input, config)
#      40 except ParentCommand as exc:
#      41     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:622, in RunnableSeq.invoke(self, input, config, **kwargs)
#     620     # run in context
#     621     with set_config_context(config, run) as context:
# --> 622         input = context.run(step.invoke, input, config, **kwargs)
#     623 else:
#     624     input = step.invoke(input, config)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:376, in RunnableCallable.invoke(self, input, config, **kwargs)
#     374         run_manager.on_chain_end(ret)
#     375 else:
# --> 376     ret = self.func(*args, **kwargs)
#     377 if self.recurse and isinstance(ret, Runnable):
#     378     return ret.invoke(input, config)
#
# Cell In[36], line 23, in chatbot(state)
#      22 def chatbot(state: State):
# ---> 23     return {"messages": [llm_with_tools.invoke(state["messages"])]}
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/runnables/base.py:5440, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5433 @override
#    5434 def invoke(
#    5435     self,
#    (...)
#    5438     **kwargs: Optional[Any],
#    5439 ) -> Output:
# -> 5440     return self.bound.invoke(
#    5441         input,
#    5442         self._merge_configs(config),
#    5443         **{**self.kwargs, **kwargs},
#    5444     )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:331, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     319 @override
#     320 def invoke(
#     321     self,
#    (...)
#     326     **kwargs: Any,
#     327 ) -> BaseMessage:
#     328     config = ensure_config(config)
#     329     return cast(
#     330         "ChatGeneration",
# --> 331         self.generate_prompt(
#     332             [self._convert_input(input)],
#     333             stop=stop,
#     334             callbacks=config.get("callbacks"),
#     335             tags=config.get("tags"),
#     336             metadata=config.get("metadata"),
#     337             run_name=config.get("run_name"),
#     338             run_id=config.pop("run_id", None),
#     339             **kwargs,
#     340         ).generations[0][0],
#     341     ).message
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:894, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     885 @override
#     886 def generate_prompt(
#     887     self,
#    (...)
#     891     **kwargs: Any,
#     892 ) -> LLMResult:
#     893     prompt_messages = [p.to_messages() for p in prompts]
# --> 894     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:719, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     716 for i, m in enumerate(messages):
#     717     try:
#     718         results.append(
# --> 719             self._generate_with_cache(
#     720                 m,
#     721                 stop=stop,
#     722                 run_manager=run_managers[i] if run_managers else None,
#     723                 **kwargs,
#     724             )
#     725         )
#     726     except BaseException as e:
#     727         if run_managers:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:960, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     958 else:
#     959     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 960         result = self._generate(
#     961             messages, stop=stop, run_manager=run_manager, **kwargs
#     962         )
#     963     else:
#     964         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_anthropic/chat_models.py:1102, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1100     return generate_from_stream(stream_iter)
#    1101 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# -> 1102 data = self._client.messages.create(**payload)
#    1103 return self._format_output(data, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/resources/messages/messages.py:953, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     946 if model in DEPRECATED_MODELS:
#     947     warnings.warn(
#     948         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     949         DeprecationWarning,
#     950         stacklevel=3,
#     951     )
# --> 953 return self._post(
#     954     "/v1/messages",
#     955     body=maybe_transform(
#     956         {
#     957             "max_tokens": max_tokens,
#     958             "messages": messages,
#     959             "model": model,
#     960             "metadata": metadata,
#     961             "stop_sequences": stop_sequences,
#     962             "stream": stream,
#     963             "system": system,
#     964             "temperature": temperature,
#     965             "thinking": thinking,
#     966             "tool_choice": tool_choice,
#     967             "tools": tools,
#     968             "top_k": top_k,
#     969             "top_p": top_p,
#     970         },
#     971         message_create_params.MessageCreateParams,
#     972     ),
#     973     options=make_request_options(
#     974         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     975     ),
#     976     cast_to=Message,
#     977     stream=stream or False,
#     978     stream_cls=Stream[RawMessageStreamEvent],
#     979 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1336, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1322 def post(
#    1323     self,
#    1324     path: str,
#    (...)
#    1331     stream_cls: type[_StreamT] | None = None,
#    1332 ) -> ResponseT | _StreamT:
#    1333     opts = FinalRequestOptions.construct(
#    1334         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1335     )
# -> 1336     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1013, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1010 else:
#    1011     retries_taken = 0
# -> 1013 return self._request(
#    1014     cast_to=cast_to,
#    1015     options=options,
#    1016     stream=stream,
#    1017     stream_cls=stream_cls,
#    1018     retries_taken=retries_taken,
#    1019 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1036 options = self._prepare_options(options)
#    1038 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
# -> 1039 request = self._build_request(options, retries_taken=retries_taken)
#    1040 self._prepare_request(request)
#    1042 kwargs: HttpxSendArgs = {}
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:487, in BaseClient._build_request(self, options, retries_taken)
#     484     else:
#     485         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 487 headers = self._build_headers(options, retries_taken=retries_taken)
#     488 params = _merge_mappings(self.default_query, options.params)
#     489 content_type = headers.get("Content-Type")
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:428, in BaseClient._build_headers(self, options, retries_taken)
#     418 custom_headers = options.headers or {}
#     419 headers_dict = _merge_mappings(
#     420     {
#     421         "x-stainless-timeout": str(options.timeout.read)
#    (...)
#     426     custom_headers,
#     427 )
# --> 428 self._validate_headers(headers_dict, custom_headers)
#     430 # headers are case-insensitive while dictionaries are not.
#     431 headers = httpx.Headers(headers_dict)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_client.py:180, in Anthropic._validate_headers(self, headers, custom_headers)
#     177 if isinstance(custom_headers.get("Authorization"), Omit):
#     178     return
# --> 180 raise TypeError(
#     181     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     182 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"

# %%
events = graph.stream(
    {
        "messages": [
            {
                "role": "user",
                "content": (
                    "Ya that's helpful. Maybe I'll "
                    "build an autonomous agent with it!"
                ),
            },
        ],
    },
    config,
    stream_mode="values",
)
for event in events:
    if "messages" in event:
        event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Ya that's helpful. Maybe I'll build an autonomous agent with it!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 16
#       1 events = graph.stream(
#       2     {
#       3         "messages": [
#    (...)
#      14     stream_mode="values",
#      15 )
# ---> 16 for event in events:
#      17     if "messages" in event:
#      18         event["messages"][-1].pretty_print()
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/__init__.py:2356, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2350     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2351     # computation proceeds in steps, while there are channel updates.
#    2352     # Channel updates from step N are only visible in step N+1
#    2353     # channels are guaranteed to be immutable for the duration of the step,
#    2354     # with channel updates applied only at the transition between steps.
#    2355     while loop.tick(input_keys=self.input_channels):
# -> 2356         for _ in runner.tick(
#    2357             loop.tasks.values(),
#    2358             timeout=self.step_timeout,
#    2359             retry_policy=self.retry_policy,
#    2360             get_waiter=get_waiter,
#    2361         ):
#    2362             # emit output
#    2363             yield from output()
#    2364 # emit output
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/runner.py:158, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     156 t = tasks[0]
#     157 try:
# --> 158     run_with_retry(
#     159         t,
#     160         retry_policy,
#     161         configurable={
#     162             CONFIG_KEY_CALL: partial(
#     163                 _call,
#     164                 weakref.ref(t),
#     165                 retry=retry_policy,
#     166                 futures=weakref.ref(futures),
#     167                 schedule_task=self.schedule_task,
#     168                 submit=self.submit,
#     169                 reraise=reraise,
#     170             ),
#     171         },
#     172     )
#     173     self.commit(t, None)
#     174 except Exception as exc:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/retry.py:39, in run_with_retry(task, retry_policy, configurable)
#      37     task.writes.clear()
#      38     # run the task
# ---> 39     return task.proc.invoke(task.input, config)
#      40 except ParentCommand as exc:
#      41     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:622, in RunnableSeq.invoke(self, input, config, **kwargs)
#     620     # run in context
#     621     with set_config_context(config, run) as context:
# --> 622         input = context.run(step.invoke, input, config, **kwargs)
#     623 else:
#     624     input = step.invoke(input, config)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langgraph/utils/runnable.py:376, in RunnableCallable.invoke(self, input, config, **kwargs)
#     374         run_manager.on_chain_end(ret)
#     375 else:
# --> 376     ret = self.func(*args, **kwargs)
#     377 if self.recurse and isinstance(ret, Runnable):
#     378     return ret.invoke(input, config)
#
# Cell In[36], line 23, in chatbot(state)
#      22 def chatbot(state: State):
# ---> 23     return {"messages": [llm_with_tools.invoke(state["messages"])]}
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/runnables/base.py:5440, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5433 @override
#    5434 def invoke(
#    5435     self,
#    (...)
#    5438     **kwargs: Optional[Any],
#    5439 ) -> Output:
# -> 5440     return self.bound.invoke(
#    5441         input,
#    5442         self._merge_configs(config),
#    5443         **{**self.kwargs, **kwargs},
#    5444     )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:331, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     319 @override
#     320 def invoke(
#     321     self,
#    (...)
#     326     **kwargs: Any,
#     327 ) -> BaseMessage:
#     328     config = ensure_config(config)
#     329     return cast(
#     330         "ChatGeneration",
# --> 331         self.generate_prompt(
#     332             [self._convert_input(input)],
#     333             stop=stop,
#     334             callbacks=config.get("callbacks"),
#     335             tags=config.get("tags"),
#     336             metadata=config.get("metadata"),
#     337             run_name=config.get("run_name"),
#     338             run_id=config.pop("run_id", None),
#     339             **kwargs,
#     340         ).generations[0][0],
#     341     ).message
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:894, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     885 @override
#     886 def generate_prompt(
#     887     self,
#    (...)
#     891     **kwargs: Any,
#     892 ) -> LLMResult:
#     893     prompt_messages = [p.to_messages() for p in prompts]
# --> 894     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:719, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     716 for i, m in enumerate(messages):
#     717     try:
#     718         results.append(
# --> 719             self._generate_with_cache(
#     720                 m,
#     721                 stop=stop,
#     722                 run_manager=run_managers[i] if run_managers else None,
#     723                 **kwargs,
#     724             )
#     725         )
#     726     except BaseException as e:
#     727         if run_managers:
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:960, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     958 else:
#     959     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 960         result = self._generate(
#     961             messages, stop=stop, run_manager=run_manager, **kwargs
#     962         )
#     963     else:
#     964         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/langchain_anthropic/chat_models.py:1102, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1100     return generate_from_stream(stream_iter)
#    1101 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# -> 1102 data = self._client.messages.create(**payload)
#    1103 return self._format_output(data, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/resources/messages/messages.py:953, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     946 if model in DEPRECATED_MODELS:
#     947     warnings.warn(
#     948         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     949         DeprecationWarning,
#     950         stacklevel=3,
#     951     )
# --> 953 return self._post(
#     954     "/v1/messages",
#     955     body=maybe_transform(
#     956         {
#     957             "max_tokens": max_tokens,
#     958             "messages": messages,
#     959             "model": model,
#     960             "metadata": metadata,
#     961             "stop_sequences": stop_sequences,
#     962             "stream": stream,
#     963             "system": system,
#     964             "temperature": temperature,
#     965             "thinking": thinking,
#     966             "tool_choice": tool_choice,
#     967             "tools": tools,
#     968             "top_k": top_k,
#     969             "top_p": top_p,
#     970         },
#     971         message_create_params.MessageCreateParams,
#     972     ),
#     973     options=make_request_options(
#     974         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     975     ),
#     976     cast_to=Message,
#     977     stream=stream or False,
#     978     stream_cls=Stream[RawMessageStreamEvent],
#     979 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1336, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1322 def post(
#    1323     self,
#    1324     path: str,
#    (...)
#    1331     stream_cls: type[_StreamT] | None = None,
#    1332 ) -> ResponseT | _StreamT:
#    1333     opts = FinalRequestOptions.construct(
#    1334         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1335     )
# -> 1336     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1013, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1010 else:
#    1011     retries_taken = 0
# -> 1013 return self._request(
#    1014     cast_to=cast_to,
#    1015     options=options,
#    1016     stream=stream,
#    1017     stream_cls=stream_cls,
#    1018     retries_taken=retries_taken,
#    1019 )
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1036 options = self._prepare_options(options)
#    1038 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
# -> 1039 request = self._build_request(options, retries_taken=retries_taken)
#    1040 self._prepare_request(request)
#    1042 kwargs: HttpxSendArgs = {}
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:487, in BaseClient._build_request(self, options, retries_taken)
#     484     else:
#     485         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 487 headers = self._build_headers(options, retries_taken=retries_taken)
#     488 params = _merge_mappings(self.default_query, options.params)
#     489 content_type = headers.get("Content-Type")
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_base_client.py:428, in BaseClient._build_headers(self, options, retries_taken)
#     418 custom_headers = options.headers or {}
#     419 headers_dict = _merge_mappings(
#     420     {
#     421         "x-stainless-timeout": str(options.timeout.read)
#    (...)
#     426     custom_headers,
#     427 )
# --> 428 self._validate_headers(headers_dict, custom_headers)
#     430 # headers are case-insensitive while dictionaries are not.
#     431 headers = httpx.Headers(headers_dict)
#
# File ~/miniforge3/envs/genai/lib/python3.10/site-packages/anthropic/_client.py:180, in Anthropic._validate_headers(self, headers, custom_headers)
#     177 if isinstance(custom_headers.get("Authorization"), Omit):
#     178     return
# --> 180 raise TypeError(
#     181     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     182 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
